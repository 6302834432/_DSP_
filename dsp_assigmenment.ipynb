# %%
import numpy as np 
import pandas as pd 
import folium
from branca.element import Figure
fig3=Figure(width=1000,height=350)
map3=folium.Map(location=[16.7850, 80.8488])
fig3.add_child(map3)
coordinates=[[16.7850, 80.8488],[16.769200333577626, 80.87926439525724],[16.75670845487423, 80.8888774315797],
             [16.69292135755772, 80.94106248590161],[16.6356702,80.9715168],[16.743558228200474, 81.09416179522118],
             [16.8084237,81.2610188],[16.81064253075948, 81.36403443892438],[16.82211118823983, 81.42350640190118],
             [16.81181706360236, 81.57449591090327],[16.75588659221565, 81.67903471844313],[16.749500121687152, 81.73795854558975],
             [16.655963770175386, 81.73991126401799],[16.62576739212933, 81.74046419123827],[16.48531845590538, 81.71392413221217],
             [16.45456506210658, 81.78690929453396],[16.457150124039224, 81.80446444580052],[16.463513210680453, 81.835980765894],
             [16.47531088120654, 81.83736306063496],[16.476503864080087, 81.84095702696139]]
coordinates2=[[16.7850, 80.8488],[16.676808046111862, 80.94518234947951],[16.676150280665844, 80.9474139471972],[16.678781328876855, 81.02294494687368],
              [16.582724658221636, 81.29210996390252],[16.576143675746362, 81.37313412719182],[16.53731130178177, 81.52126051973025],
              [16.538627781520393, 81.6283772101805],[16.51097982172814, 81.71626782798585],[16.478060427269753, 81.73412060972754],
              [16.450403811216333, 81.78767895495267],[16.46884199365868, 81.83437084566177]]
coordinates3=[[16.809414775867573, 81.5292191293198],[16.758023432936017, 81.52776837427943],
              [16.716344582403824, 81.53792365956198],[16.68855362112818, 81.59885537125727],[16.68438462818647, 81.60320763637837],
              [16.637129692030523, 81.6626885930333],[16.602375982052607, 81.6423780224682],[16.54814764606624, 81.63657500230674],[16.53284971443166, 81.66559010311404],[16.51894145162561, 81.71491577448641]]
f1=folium.FeatureGroup("1 st way")
f2=folium.FeatureGroup("2nd way")
f3=folium.FeatureGroup("3rd way")
line_1=folium.vector_layers.PolyLine(coordinates,popup='path 1',tooltip='1way',color='black',weight=10).add_to(f1)
f1.add_to(map3)
line_2=folium.vector_layers.PolyLine(coordinates2,popup='<b>Path 2</b>',tooltip="2way",color='purple',weight=10).add_to(f2)
f2.add_to(map3)
line3=folium.vector_layers.PolyLine(coordinates3,popup='<b>Path 2</b>',tooltip="2way",color='red',weight=10).add_to(f3)
f3.add_to(map3)
map3
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#
import folium
folium.Marker(location=[16.7850, 80.8488],popup="nuzvid bus stand",icon=folium.Icon(color="blue",prefix="fa",icon="fa-bus")).add_to(map3)
folium.Marker(location=[16.75670845487423, 80.888877431579],popup="hanuman junction",icon=folium.Icon(color="blue",prefix="fa",icon="fa-bus")).add_to(map3)
folium.Marker(location=[16.812091702995147, 81.36958702788534],popup="kakiram restuarant",icon=folium.Icon(color="pink",prefix="fa",icon=" fa-cutlery")).add_to(map3)
folium.Marker(location=[16.804218938483174, 80.85065823341769],popup="dwaraka resturant",icon=folium.Icon(color="pink",prefix="fa",icon=" fa-cutlery")).add_to(map3)
folium.Marker(location=[16.82434872247591, 81.52508888008252],popup="court",icon=folium.Icon(color="black",prefix="fa",icon="fa-gavel")).add_to(map3)
folium.Marker(location=[16.536465009979278, 81.18926727719672],popup="petrol bunk",icon=folium.Icon(color="orange",prefix="fa",icon="fa-battery-4")).add_to(map3)
folium.Marker(location=[16.757508088613058, 81.67129239010093],popup="taunku bus stand",icon=folium.Icon(color="blue",prefix="fa",icon="fa-bus")).add_to(map3)
folium.Marker(location=[16.507875311056516, 81.71261019923965],popup="palokollu bus stand",icon=folium.Icon(color="blue",prefix="fa",icon="fa-bus")).add_to(map3)
folium.Marker(location=[16.518999135905165, 81.70494249165186],popup="government hospital",icon=folium.Icon(color="green",prefix="fa",icon="fa-bed")).add_to(map3)
folium.Marker(location=[16.58469889858676, 81.36334246003108],popup="akvidu bus stand",icon=folium.Icon(color="blue",prefix="fa",icon="fa-bus")).add_to(map3)
folium.Marker(location=[16.548980975871416, 81.50816732640192],popup="gvt hospital",icon=folium.Icon(color="green",prefix="fa",icon="fa-bed")).add_to(map3)
folium.Marker(location=[16.463513210680453, 81.835980765894],popup="devi temple",icon=folium.Icon(color="green",prefix="fa",icon="fa-flag-checkered")).add_to(map3)
folium.Marker(location=[16.463513210680453, 81.835980765894],popup="devi temple",icon=folium.Icon(color="green",prefix="fa",icon="fa-flag-checkered")).add_to(map3)
folium.Marker(location=[16.68855362112818, 81.59885537125727],popup="resturant",icon=folium.Icon(color="pink",prefix="fa",icon="fa-cutlery")).add_to(map3)
map3
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
